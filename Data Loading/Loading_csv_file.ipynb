# %%
import pandas as pd
import csv

# %%
with open("real_drug_dataset.csv",'r') as d:
    res = csv.reader(d)
    data = pd.DataFrame(res)
data.head()
# Out:
#                0    1       2             3              4          5  \
# 0  ï»¿Patient_ID  Age  Gender     Condition      Drug_Name  Dosage_mg
# 1          P0001   56    Male     Infection  Ciprofloxacin         50
# 2          P0002   69    Male  Hypertension     Metoprolol        500
# 3          P0003   46  Female    Depression      Bupropion        100
# 4          P0004   32    Male      Diabetes      Glipizide        850
#
#                          6                7                  8
# 0  Treatment_Duration_days     Side_Effects  Improvement_Score
# 1                        9           Nausea                8.5
# 2                       24        Tiredness                8.7
# 3                       25        Dry mouth                5.4
# 4                       44  Low blood sugar                6.4

# %%
t = pd.read_csv("real_drug_dataset.csv")
t.head()
# Out:
#   Patient_ID  Age  Gender     Condition      Drug_Name  Dosage_mg  \
# 0      P0001   56    Male     Infection  Ciprofloxacin         50
# 1      P0002   69    Male  Hypertension     Metoprolol        500
# 2      P0003   46  Female    Depression      Bupropion        100
# 3      P0004   32    Male      Diabetes      Glipizide        850
# 4      P0005   60    Male    Depression      Bupropion        850
#
#    Treatment_Duration_days     Side_Effects  Improvement_Score
# 0                        9           Nausea                8.5
# 1                       24        Tiredness                8.7
# 2                       25        Dry mouth                5.4
# 3                       44  Low blood sugar                6.4
# 4                       35          Anxiety                5.3

# %% [markdown]
# 1. Read specific columns using read_csv

# %%
temp = pd.read_csv("real_drug_dataset.csv",usecols=["Age","Gender"])
temp.head()
# Out:
#    Age  Gender
# 0   56    Male
# 1   69    Male
# 2   46  Female
# 3   32    Male
# 4   60    Male

# %% [markdown]
# 2.Setting an Index Column (index_col)

# %%
temp = pd.read_csv("real_drug_dataset.csv",index_col=0)
temp.head()
# Out:
#             Age  Gender     Condition      Drug_Name  Dosage_mg  \
# Patient_ID
# P0001        56    Male     Infection  Ciprofloxacin         50
# P0002        69    Male  Hypertension     Metoprolol        500
# P0003        46  Female    Depression      Bupropion        100
# P0004        32    Male      Diabetes      Glipizide        850
# P0005        60    Male    Depression      Bupropion        850
#
#             Treatment_Duration_days     Side_Effects  Improvement_Score
# Patient_ID
# P0001                             9           Nausea                8.5
# P0002                            24        Tiredness                8.7
# P0003                            25        Dry mouth                5.4
# P0004                            44  Low blood sugar                6.4
# P0005                            35          Anxiety                5.3

# %% [markdown]
# 3. Handling Missing Values Using read_csv

# %%
temp = pd.read_csv("real_drug_dataset.csv",na_values=["N/A", "Unknown"])
temp.head()
# Out:
#   Patient_ID  Age  Gender     Condition      Drug_Name  Dosage_mg  \
# 0      P0001   56    Male     Infection  Ciprofloxacin         50
# 1      P0002   69    Male  Hypertension     Metoprolol        500
# 2      P0003   46  Female    Depression      Bupropion        100
# 3      P0004   32    Male      Diabetes      Glipizide        850
# 4      P0005   60    Male    Depression      Bupropion        850
#
#    Treatment_Duration_days     Side_Effects  Improvement_Score
# 0                        9           Nausea                8.5
# 1                       24        Tiredness                8.7
# 2                       25        Dry mouth                5.4
# 3                       44  Low blood sugar                6.4
# 4                       35          Anxiety                5.3

# %% [markdown]
# 4. Using skiprows in read_csv()

# %%
temp = pd.read_csv("real_drug_dataset.csv",skiprows=[2,3,4,5,6])
temp.head()
# Out:
#   Patient_ID  Age Gender    Condition      Drug_Name  Dosage_mg  \
# 0      P0001   56   Male    Infection  Ciprofloxacin         50
# 1      P0007   78   Male     Diabetes      Glipizide        250
# 2      P0008   38   Male  Pain Relief    Paracetamol        100
# 3      P0009   56   Male   Depression   Escitalopram        850
# 4      P0010   75   Male     Diabetes      Metformin        850
#
#    Treatment_Duration_days  Side_Effects  Improvement_Score
# 0                        9        Nausea                8.5
# 1                       40        Nausea                6.5
# 2                       15  Liver issues                8.2
# 3                       56        Nausea                9.0
# 4                       19        Nausea                9.1
